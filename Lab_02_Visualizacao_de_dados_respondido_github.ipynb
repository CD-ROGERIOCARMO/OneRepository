# %% [markdown]
# ---
# <img src="https://ead.ufes.br/pluginfile.php/188418/course/summary/Banner%20IA%20e%20CD.png" style="float: right;">
#
# # Visualização de Dados 📈
#
#
# Um pouco de como representar dados de forma visual!
#
# **Objetivos**
#
# Aprender o básico de visualização de dados por meio de gráficos de linhas, barra e histograma de dados.
#
# **Resultados Esperados**
#
# 1. Ferramentas simples para exploração de dados
# 1. Aprender a base de pandas para realizar um plot simples
# 1. Aprender conceitos básicos de visualização dados
#
#
# Material Adaptado do [DSC10 (UCSD)](https://dsc10.com/)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('ggplot')

from IPython.display import HTML, display, IFrame

# %% [markdown]
# ### Agenda
#
# - Por que visualizar?
# - Terminologia.
# - Gráficos de dispersão.
# - Gráficos de linha.
# - Gráficos de barra.

# %% [markdown]
# ## Por que visualizar?

# %% [markdown]
# ### Por que visualizar?

# %% [markdown]
# - Os computadores são melhores que os humanos para processar números, mas os humanos são melhores para identificar padrões visuais.

# %% [markdown]
# - As visualizações permitem-nos compreender rapidamente muitos dados – tornam mais fácil identificar tendências e comunicar os nossos resultados a outras pessoas.

# %% [markdown]
# - Existem vários tipos de visualizações; nesta aula, veremos gráficos de dispersão, gráficos de linhas, gráficos de barras e histogramas, mas existem muitos outros.
# - A escolha certa depende do tipo de dados.

# %% [markdown]
# ## 1. Terminologia

# %% [markdown]
# ### Indivíduos (amostras) e variáveis
#
# ![ind-var.png](data:image/png;base64,...)

# %% [markdown]
# - <span style="color:#6d9eeb"><b>Indivíduo (linha):</b></span> Pessoa/lugar/coisa para a qual os dados são registrados. Também chamada de **observação**.

# %% [markdown]
# - <span style="color:#ff9900"><b>Variável (coluna):</b></span> Algo que é registrado para cada indivíduo. Também chamado de **recurso**.

# %% [markdown]
# ### Tipos de variáveis
#
# Existem dois tipos principais de variáveis:
#
# - **Numérico**: Faz sentido fazer aritmética com os valores.
# - **Categórico**: Os valores se enquadram em categorias, que podem ou não ter alguma _ordem_ para eles.

# %% [markdown]
# ### Exemplos de variáveis ​​numéricas

# %% [markdown]
# - Salários dos jogadores da NBA 🏀.
# - Individual: um jogador da NBA.
# - Variável: seu salário.

# %% [markdown]
# - Ganhos brutos do filme 💰.
# - Individual: um filme.
# - Variável: seu rendimento bruto.

# %% [markdown]
# - Doses de reforço administradas por dia 💉.
# - Individual: data.
# - Variável: número de doses de reforço administradas naquela data.

# %% [markdown]
# ### Exemplos de variáveis ​​​​categóricas

# %% [markdown]
# - Gêneros de filmes 🎬.
# - Individual: um filme.
# - Variável: seu gênero.

# %% [markdown]
# - CEPs 🏠.
# - Pessoa física: residente nos EUA.
# - Variável: CEP.
# - Apesar de parecerem números, os CEPs são categóricos (a aritmética não faz sentido).

# %% [markdown]
# - Nível de experiência anterior em programação para alunos do DSC 10 🧑‍🎓.
# - Individual: aluno do DSC 10.
# - Variável: seu nível de experiência anterior em programação, por ex. nenhum, baixo, médio ou alto.
# - Existe uma _ordem_ para essas categorias!

# %% [markdown]
# ### Pergunta 1.1 ✅
#
# Qual destas **não** é uma variável numérica?
#
# A. Economia de combustível em milhas por galão.
#
# B. Número de trimestres na UFES.
#
# C. Idade dos alunos da UFES
#
# D. Número da conta bancária.
#
# E. Mais de uma destas não são variáveis ​​numéricas.

# %%
#@title Solução

D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-b71e65304cf9> in <cell line: 3>()
#       1 #@title Solução
#       2
# ----> 3 D
#
# NameError: name 'D' is not defined

# %% [markdown]
# ### Tipos de visualizações
#
# O tipo de visualização que criamos depende dos tipos de variáveis ​​que estamos visualizando.
#
# - **Gráfico de dispersão**: numérico versus numérico.
# - **Gráfico de linhas**: numérico sequencial (tempo) vs.
# - **Gráfico de barras**: categórico vs. numérico.
# - **Histograma**: numérico.
#
# **Observação:** Podemos trocar as palavras "plot", "chart" e "graph"; todos eles significam a mesma coisa.

# %% [markdown]
# ## 2. Gráficos de dispersão

# %% [markdown]
# ### Conjunto de dados dos 50 atores de maior bilheteria

# %% [markdown]
# |Coluna |Conteúdo|
# |----------|------------|
# `'Ator'`|Nome do ator
# `'Total Bruto'`| Receita total bruta de bilheteria interna, em milhões de dólares, de todos os filmes do ator
# `'Número de filmes'`| O número de filmes em que o ator esteve
# `'Média por Filme'`| Total bruto dividido pelo número de filmes
# `'Filme #1'`| O filme de maior bilheteria em que o ator já esteve
# `'Bruto'`| Receita bruta de bilheteria interna, em milhões de dólares, do filme número 1 do ator

# %%
actors = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/actors.csv').set_index('Actor')
actors

# %% [markdown]
# ### Gráficos de dispersão
#
# Qual é a relação entre `'Número de Filmes'` e `'Total Bruto'`?

# %%
actors.plot(kind='scatter', x='Number of Movies', y='Total Gross');

# %% [markdown]
# ### Gráficos de dispersão
#
# - Os gráficos de dispersão visualizam a relação entre duas variáveis ​​numéricas.

# %% [markdown]
# ### Gráficos de dispersão
#
# Qual é a relação entre `'Número de Filmes'` e `'Média por Filme'`?

# %%
actors.plot(kind='scatter', x='Number of Movies', y='Average per Movie');

# %% [markdown]
# Observe que no gráfico acima, há uma associação _negativa_ e um valor discrepante.

# %% [markdown]
# ### Quem esteve em 60 ou mais filmes?

# %%
actors[actors.get('Number of Movies') >= 60]

# %% [markdown]
# ### Quem é o estranho?
#
# Quem quer que sejam, fizeram poucos filmes de alta bilheteria.

# %%
actors[actors.get('Number of Movies') < 10]

# %% [markdown]
# ### Anthony Daniels
#
# <center><img src='https://images.immediate.co.uk/production/volatile/sites/3/2019/11/SeeThreepio-de03213.jpg' width=414></center>

# %% [markdown]
# ## 3. Gráficos de linha 📉

# %% [markdown]
# ### Conjunto de dados agregando filmes por ano

# %% [markdown]
# |Coluna| Conteúdo|
# |------|-----------|
# `'Ano'`| Ano
# `'Total Bruto em Bilhões'`| Total bruto de bilheteria doméstica, em bilhões de dólares, de todos os filmes lançados
# `'Número de filmes'`| Número de filmes lançados
# `'Filme #1'`| Filme de maior bilheteria

# %%
movies_by_year = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/movies_by_year.csv').set_index('Year')
movies_by_year

# %% [markdown]
# ### Gráficos de linha
#
# Como o número de filmes mudou ao longo do tempo? 🤔

# %%
movies_by_year.plot(kind='line', y='Number of Movies');

# %% [markdown]
# ### Gráficos de linha
#
# - Os gráficos de linhas mostram tendências em variáveis ​​numéricas ao longo do tempo.
# - Para criar um a partir de um DataFrame `df`, use
# ```
# df.plot(
#     kind='line',
#     x=x_column_for_horizontal,
#     y=y_column_for_vertical
# )
# ```

# %% [markdown]
# ### Dica de plotagem
#
# - **Dica**: se você quiser que o eixo x seja o índice, omita o argumento `x=`!
# - Não funciona para gráficos de dispersão, mas funciona para a maioria dos outros tipos de gráficos.

# %% [markdown]
# ### Desde o ano 2000
#
# Podemos criar um gráfico de linhas de apenas 2.000 em diante consultando `movies_by_year` antes de chamar `.plot`.

# %%
movies_by_year[movies_by_year.index >= 2000].plot(kind='line', y='Number of Movies');

# %% [markdown]
# O que você acha que explica as quedas em torno de 2008 e 2020?

# %% [markdown]
# ### Como isso afetou o total bruto?

# %%
movies_by_year[movies_by_year.index >= 2000].plot(kind='line', y='Total Gross in Billions');

# %% [markdown]
# ### Pergunta 3.1 -  Qual foi o filme de maior bilheteria de 2016? 🐟
#
# >

# %%
movies_2016 = movies_by_year[movies_by_year.index == 2016]
max_2016 = movies_2016.loc[movies_2016['Total Gross in Billions'].idxmax()]
max_2016
# Out:
# Total Gross in Billions           11.38
# Number of Movies                    855
# #1 Movie                   Finding Dory
# Name: 2016, dtype: object

# %%
#@title Solução
movies_2016 = movies_by_year[movies_by_year.index == 2016]
max_2016 = movies_2016.loc[movies_2016['Total Gross in Billions'].idxmax()]
max_2016
# Out:
# Total Gross in Billions           11.38
# Number of Movies                    855
# #1 Movie                   Finding Dory
# Name: 2016, dtype: object

# %% [markdown]
# ### 4. Gráficos de barras 📊

# %% [markdown]
# ### Conjunto de dados das 200 músicas mais tocadas no mundo no Spotify no Domingo 11/08/24 (Dia dos pais)
#
#
#
# [Downloaded daqui – Você pode fazer o download de outros dias aqui!](https://spotifycharts.com/regional)

# %%
charts = (pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')
          .set_index('rank')
          .get(['track_name', 'artist_names', 'streams', 'uri'])
         )
charts
# Out:
#                         track_name                artist_names  streams  \
# rank
# 1                              Who                       Jimin  8325788
# 2               BIRDS OF A FEATHER               Billie Eilish  7743988
# 3                         Espresso           Sabrina Carpenter  5766013
# 4             Please Please Please           Sabrina Carpenter  5306128
# 5     Si Antes Te Hubiera Conocido                     KAROL G  5118004
# ...                            ...                         ...      ...
# 196                        ADIVINO      Myke Towers, Bad Bunny  1146694
# 197        Cold Heart - PNAU Remix  Elton John, Dua Lipa, PNAU  1145374
# 198        Cowgirls (feat. ERNEST)       Morgan Wallen, ERNEST  1140582
# 199                       Believer             Imagine Dragons  1138138
# 200            Young And Beautiful                Lana Del Rey  1136245
#
#                                        uri
# rank
# 1     spotify:track:7tI8dRuH2Yc6RuoTjxo4dU
# ...

# %% [markdown]
# ### Gráficos de barra
#
# Quantos streams as 10 músicas mais populares têm?

# %%
charts
# Out:
#                         track_name                artist_names  streams  \
# rank
# 1                              Who                       Jimin  8325788
# 2               BIRDS OF A FEATHER               Billie Eilish  7743988
# 3                         Espresso           Sabrina Carpenter  5766013
# 4             Please Please Please           Sabrina Carpenter  5306128
# 5     Si Antes Te Hubiera Conocido                     KAROL G  5118004
# ...                            ...                         ...      ...
# 196                        ADIVINO      Myke Towers, Bad Bunny  1146694
# 197        Cold Heart - PNAU Remix  Elton John, Dua Lipa, PNAU  1145374
# 198        Cowgirls (feat. ERNEST)       Morgan Wallen, ERNEST  1140582
# 199                       Believer             Imagine Dragons  1138138
# 200            Young And Beautiful                Lana Del Rey  1136245
#
#                                        uri
# rank
# 1     spotify:track:7tI8dRuH2Yc6RuoTjxo4dU
# ...

# %%
charts.take(np.arange(10))
# Out:
#                          track_name               artist_names  streams  \
# rank
# 1                               Who                      Jimin  8325788
# 2                BIRDS OF A FEATHER              Billie Eilish  7743988
# 3                          Espresso          Sabrina Carpenter  5766013
# 4              Please Please Please          Sabrina Carpenter  5306128
# 5      Si Antes Te Hubiera Conocido                    KAROL G  5118004
# 6                  Good Luck, Babe!              Chappell Roan  5116313
# 7                         Big Dawgs         Hanumankind, Kalmi  4135984
# 8                         Gata Only        FloyyMenor, Cris Mj  4130395
# 9     Guess featuring Billie Eilish  Charli xcx, Billie Eilish  4123663
# 10                 Beautiful Things               Benson Boone  3945458
#
#                                        uri
# rank
# 1     spotify:track:7tI8dRuH2Yc6RuoTjxo4dU
# 2     spotify:track:6dOtVTDdiauQNBQEDOtlAB
# ...

# %%
charts.take(np.arange(10)).plot(kind='barh', x='track_name', y='streams');

# %% [markdown]
# ### Gráficos de barra
#
# - Os gráficos de barras visualizam a relação entre uma variável categórica e uma variável numérica.
# - Em um gráfico de barras...
# - A espessura e o espaçamento das barras são arbitrários.
# - A ordem dos rótulos categóricos não importa.
# - Para criar um a partir de um DataFrame `df`, use
# ```
# df.plot(
#     kind='barh',
#     x=categorical_column_name,
#     y=numerical_column_name
# )
# ```
# - O **"h"** em `'barh'` significa **"horizontal"**.
# - É mais fácil ler os rótulos desta forma.
# - No gráfico anterior, definimos `y='Streams'` mesmo que os streams sejam medidos pelo comprimento do eixo x.

# %%
# The bars appear in the opposite order relative to the DataFrame
(charts
 .take(np.arange(10))
 .sort_values(by='streams')
 .plot(kind='barh', x='track_name', y='streams')
);

# %% [markdown]
# ### Quantas músicas os 15 melhores artistas têm entre os 200 melhores?

# %% [markdown]
# Primeiro, vamos criar um DataFrame com uma única coluna que descreve o número de músicas entre as 200 melhores por artista. Isso envolve usar `.groupby` com `.count()`. Como queremos uma linha por artista, agruparemos por `'nomes_artistas'`.

# %%
charts
# Out:
#                         track_name                artist_names  streams  \
# rank
# 1                              Who                       Jimin  8325788
# 2               BIRDS OF A FEATHER               Billie Eilish  7743988
# 3                         Espresso           Sabrina Carpenter  5766013
# 4             Please Please Please           Sabrina Carpenter  5306128
# 5     Si Antes Te Hubiera Conocido                     KAROL G  5118004
# ...                            ...                         ...      ...
# 196                        ADIVINO      Myke Towers, Bad Bunny  1146694
# 197        Cold Heart - PNAU Remix  Elton John, Dua Lipa, PNAU  1145374
# 198        Cowgirls (feat. ERNEST)       Morgan Wallen, ERNEST  1140582
# 199                       Believer             Imagine Dragons  1138138
# 200            Young And Beautiful                Lana Del Rey  1136245
#
#                                        uri
# rank
# 1     spotify:track:7tI8dRuH2Yc6RuoTjxo4dU
# ...

# %%
songs_per_artist = charts.groupby('artist_names').count()
songs_per_artist
# Out:
#                                                track_name  streams  uri
# artist_names
# *NSYNC                                                  1        1    1
# AC/DC                                                   1        1    1
# Adam Port, Stryv, Keinemusik, Orso, Malachiii           1        1    1
# Adele                                                   3        3    3
# Alphaville                                              1        1    1
# ...                                                   ...      ...  ...
# Zach Bryan                                              3        3    3
# Zach Bryan, Kacey Musgraves                             1        1    1
# a-ha                                                    1        1    1
# d4vd                                                    1        1    1
# ¥$, Kanye West, Ty Dolla $ign                           1        1    1
#
# [160 rows x 3 columns]

# %% [markdown]
# Usando `.sort_values` e `.take`, manteremos apenas os 15 melhores artistas. Observe que todas as colunas em `songs_per_artist` contêm as mesmas informações (isso é uma consequência do uso de `.count()`).

# %%
top_15_artists = (songs_per_artist
                  .sort_values('streams', ascending=False)
                  .take(np.arange(15)))
top_15_artists
# Out:
#                               track_name  streams  uri
# artist_names
# Chappell Roan                          5        5    5
# Billie Eilish                          5        5    5
# Taylor Swift                           4        4    4
# Bruno Mars                             4        4    4
# Sabrina Carpenter                      4        4    4
# Coldplay                               4        4    4
# Adele                                  3        3    3
# Zach Bryan                             3        3    3
# KAROL G                                3        3    3
# Creedence Clearwater Revival           2        2    2
# Jimin                                  2        2    2
# Lana Del Rey                           2        2    2
# Imagine Dragons                        2        2    2
# Charli xcx                             2        2    2
# Eminem                                 2        2    2

# %% [markdown]
# Usando `.assign` e `.drop`, criaremos uma coluna chamada `'count'` que contém as mesmas informações que as outras 3 colunas contêm, e então `.get` apenas essa coluna (ou equivalentemente, eliminaremos o outras 3 colunas).

# %%
# If we give .get a list, it will return a DataFrame instead of a Series!
top_15_artists = (top_15_artists
                  .assign(count=top_15_artists.get('streams'))
                  .get(['count']))
top_15_artists
# Out:
#                               count
# artist_names
# Chappell Roan                     5
# Billie Eilish                     5
# Taylor Swift                      4
# Bruno Mars                        4
# Sabrina Carpenter                 4
# Coldplay                          4
# Adele                             3
# Zach Bryan                        3
# KAROL G                           3
# Creedence Clearwater Revival      2
# Jimin                             2
# Lana Del Rey                      2
# Imagine Dragons                   2
# Charli xcx                        2
# Eminem                            2

# %% [markdown]
# Antes de chamar `.plot(kind='barh', y='count')`, classificaremos `top_15_artists` por `'count'` em ordem **crescente**. Isso ocorre porque, estranhamente, o Python inverte a ordem das linhas ao criar barras em gráficos de barras horizontais.

# %%
top_15_artists.sort_values(by='count').plot(kind='barh', y='count');

# %% [markdown]
# ### Gráficos de barras verticais
#
# Para criar um gráfico de barras verticais, use `kind='bar'` em vez de `kind='barh'`. No entanto, geralmente são mais difíceis de ler.

# %%
top_15_artists.plot(kind='bar', y='count');

# %% [markdown]
# ### À parte: quantas transmissões as músicas do The Weeknd na parada receberam?

# %%
(charts
 [charts.get('artist_names') == 'The Weeknd']
 .sort_values('streams')
 .plot(kind='barh', x='track_name', y='streams')
);

# %% [markdown]
# Parece que estamos perdendo algumas músicas populares...

# %% [markdown]
# ### Como incluímos músicas em destaque também?
#
# Resposta: Usando `.str.contains`.

# %%
weeknd = charts[charts.get('artist_names').str.contains('The Weeknd')]
weeknd
# Out:
#                                           track_name  \
# rank
# 20    One Of The Girls (with JENNIE, Lily Rose Depp)
# 74                                           Starboy
# 80                                   Blinding Lights
# 119                                      Die For You
#
#                             artist_names  streams  \
# rank
# 20    The Weeknd, JENNIE, Lily-Rose Depp  2713901
# 74                 The Weeknd, Daft Punk  1690128
# 80                            The Weeknd  1634358
# 119                           The Weeknd  1394560
#
#                                        uri
# rank
# 20    spotify:track:7CyPwkp0oE8Ro9Dd5CUDjW
# 74    spotify:track:7MXVkk9YMctZqd1Srtv4MB
# 80    spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 119   spotify:track:2LBqCSwhJGcFQeTHMVGwy3

# %%
weeknd.sort_values('streams').plot(kind='barh', x='track_name', y='streams');

# %% [markdown]
# ### Pergunta 4.1  Sua vez.
#
# Sua banda preferida está na parada mundial? Quantas músicas estão na parada?
#
# Substitua a busca por `The weekend` por sua banda. Cole os códigos acima no snippet abaixo.

# %%
#seu código aqui
weeknd = charts[charts.get('artist_names').str.contains('Coldplay')]
weeknd
# Out:
#                     track_name                artist_names  streams  \
# rank
# 38                Viva La Vida                    Coldplay  2083356
# 90                      Yellow                    Coldplay  1529700
# 94    Something Just Like This  The Chainsmokers, Coldplay  1502905
# 120        A Sky Full of Stars                    Coldplay  1391065
# 186                     Sparks                    Coldplay  1161457
#
#                                        uri
# rank
# 38    spotify:track:1mea3bSkSGXuIRvnydlB5b
# 90    spotify:track:3AJwUDP919kvQ9QcozQPxg
# 94    spotify:track:6RUKPb4LETWmmr3iAEQktW
# 120   spotify:track:0FDzzruyVECATHXKHFs9eJ
# 186   spotify:track:7D0RhFcb3CrfPuTJ0obrod

# %% [markdown]
# ## Demonstração divertida 🎵

# %%
#@title Spotifizer
# Run this cell, don't worry about what it does.
def show_spotify(uri):
    code = uri[uri.rfind(':')+1:]
    src = f"https://open.spotify.com/embed/track/{code}"
    width = 400
    height = 75
    display(IFrame(src, width, height))

# %% [markdown]
# #### Vamos encontrar o URI de uma música que nos interessa.

# %%
charts
# Out:
#                         track_name                artist_names  streams  \
# rank
# 1                              Who                       Jimin  8325788
# 2               BIRDS OF A FEATHER               Billie Eilish  7743988
# 3                         Espresso           Sabrina Carpenter  5766013
# 4             Please Please Please           Sabrina Carpenter  5306128
# 5     Si Antes Te Hubiera Conocido                     KAROL G  5118004
# ...                            ...                         ...      ...
# 196                        ADIVINO      Myke Towers, Bad Bunny  1146694
# 197        Cold Heart - PNAU Remix  Elton John, Dua Lipa, PNAU  1145374
# 198        Cowgirls (feat. ERNEST)       Morgan Wallen, ERNEST  1140582
# 199                       Believer             Imagine Dragons  1138138
# 200            Young And Beautiful                Lana Del Rey  1136245
#
#                                        uri
# rank
# 1     spotify:track:7tI8dRuH2Yc6RuoTjxo4dU
# ...

# %%
#@title URI da musica Cruel Summer
favorite_song = 'Cruel Summer'
song_uri = (charts
            [charts.get('track_name') == favorite_song]
            .get('uri')
            .iloc[0])
song_uri
# Out:
# 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'

# %%
favorite_song = 'Yellow'
song_uri = (charts
            [charts.get('track_name') == favorite_song]
            .get('uri')
            .iloc[0])
song_uri
# Out:
# 'spotify:track:3AJwUDP919kvQ9QcozQPxg'

# %% [markdown]
# Veja o que acontece! 🎶

# %%
show_spotify(song_uri)
# Out:
#         <iframe
#             width="400"
#             height="75"
#             src="https://open.spotify.com/embed/track/3AJwUDP919kvQ9QcozQPxg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Experimente você mesmo!

# %% [markdown]
# ## Distribuições

# %% [markdown]
# ### Qual é a distribuição de uma variável?
#
# - A distribuição de uma variável consiste em todos os valores da variável que ocorrem nos dados, juntamente com suas frequências.
# - As distribuições ajudam você a entender:
#     - Com que frequência uma variável assume um determinado valor?_
# - Ambas as variáveis ​​categóricas e numéricas têm distribuições.

# %% [markdown]
# ### Variáveis ​​numéricas
#
# A distribuição de uma variável numérica nem sempre pode ser representada com precisão por um gráfico de barras. Por exemplo, vejamos o número de streams de cada uma das 200 músicas mais populares no Spotify Mundo. 🎵

# %%
charts = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')
charts = (charts.set_index('rank')
          .assign(million_streams = np.round(charts.get('streams')/1000000, 2))
          .get(['track_name', 'artist_names', 'streams', 'million_streams'])
         )
charts
# Out:
#                         track_name                artist_names  streams  \
# rank
# 1                              Who                       Jimin  8325788
# 2               BIRDS OF A FEATHER               Billie Eilish  7743988
# 3                         Espresso           Sabrina Carpenter  5766013
# 4             Please Please Please           Sabrina Carpenter  5306128
# 5     Si Antes Te Hubiera Conocido                     KAROL G  5118004
# ...                            ...                         ...      ...
# 196                        ADIVINO      Myke Towers, Bad Bunny  1146694
# 197        Cold Heart - PNAU Remix  Elton John, Dua Lipa, PNAU  1145374
# 198        Cowgirls (feat. ERNEST)       Morgan Wallen, ERNEST  1140582
# 199                       Believer             Imagine Dragons  1138138
# 200            Young And Beautiful                Lana Del Rey  1136245
#
#       million_streams
# rank
# 1                7.74
# 2                5.77
# ...

# %% [markdown]
# Para ver a distribuição do número de streams, precisamos agrupar pela coluna `'million_streams'`.

# %%
stream_counts = charts.groupby('million_streams').count()
stream_counts = stream_counts.assign(Count=stream_counts.get('track_name')).drop(columns=['track_name', 'artist_names', 'streams'])
stream_counts
# Out:
#                  Count
# million_streams
# 1.14                 3
# 1.15                 6
# 1.16                 7
# 1.17                 4
# 1.18                 2
# ...                ...
# 4.14                 1
# 5.12                 2
# 5.31                 1
# 5.77                 1
# 7.74                 1
#
# [105 rows x 1 columns]

# %%
stream_counts.plot(kind='bar', y='Count', figsize=(15,5));

# %% [markdown]
# ### Péssimo de visualizar
# - Isso obscurece o fato de que as duas músicas principais são atípicas, com **muito mais streams** do que as outras músicas.
#
# - O eixo horizontal deve ser numérico (como uma reta numérica), não categórico. Deve haver mais espaço entre certas barras do que outras.

# %% [markdown]
# ## Histogramas

# %% [markdown]
# ### Histogramas mostram a distribuição de variáveis ​​numéricas *sem normalizar*
#
# Em vez de um gráfico de barras, visualizaremos a distribuição de uma variável numérica com um **histograma**. Vamos ver como é um histograma de densidade para `'million_streams'`. O que você percebe nessa visualização?

# %%
# Ignore o código por enquanto.
charts.plot(
    kind='hist',
    y='million_streams',
    bins=np.arange(0, 8, 0.5),
    ec='w'  # borda branca
);

# %% [markdown]
# Agora é fácil perceber que a maioria das músicas no top 200 tiveram entre 1 e 2 milhões de streams

# %% [markdown]
# ### Primeira ideia chave por trás dos histogramas: binning 🗑️
#
# - Binning é o ato de contar o número de valores numéricos que se enquadram nos intervalos definidos por dois pontos finais. Esses intervalos são chamados de “caixas”.
# - Um valor cai em uma caixa se for **maior ou igual ao ponto final esquerdo** e **menor que o ponto final direito**.
# - [a, b): a está incluído, b não.
# - A largura de uma caixa é sua extremidade direita menos sua extremidade esquerda.

# %% [markdown]
# ### Personalizando as caixas
#
# - Por padrão, o Python agrupará seus dados em 10 compartimentos de tamanhos iguais.
# - Você pode especificar outro número de compartimentos de tamanhos iguais definindo o argumento opcional `bins` igual a algum outro valor inteiro.
# - Você também pode especificar o início e os pontos finais do compartimento personalizado definindo `bins` iguais a uma sequência de pontos finais do compartimento.
# - Pode ser um array `list` ou `numpy`.

# %%
charts.plot(
    kind='hist',
    y='million_streams',
    bins=20,
    ec='w'
);

# %%
charts.plot(
    kind='hist', y='million_streams', density=True,
    bins=[0, 1, 2, 3, 4, 5],
    ec='w'
);

# %% [markdown]
# Nos dois histogramas acima, o que é diferente e o que é igual?

# %% [markdown]
# ### Observações
# - A forma geral de todos os dois histogramas é a mesma, independentemente dos compartimentos. Esta forma é chamada de *inclinada à direita*.
# - Mais compartimentos fornecem uma imagem mais precisa e granular da distribuição da variável `'million_streams'`.
# - Os valores do eixo $y$ parecem mudar muito quando mudamos os compartimentos.

# %% [markdown]
# ### Histogramas de densidade mostram a distribuição de variáveis ​​numéricas
#
# Podemos também criar histogramas *normalizados* ou histogramas de densidade.

# %% [markdown]
# ### Ideia chave por trás dos histogramas de densidade: a área total é 1
#
# - Em um histograma de densidade, o eixo $y$ pode ser difícil de interpretar, mas foi projetado para dar ao histograma uma propriedade muito boa: $$\textbf{As barras de um histograma de densidade }$$
# $$\textbf{têm uma área total combinada de 1.}$$
# - Isso significa que a área de uma barra é igual à proporção de todos os pontos de dados que caem nessa caixa.
# - Proporções e percentagens representam a mesma coisa.
# - Uma proporção é um decimal entre 0 e 1, uma porcentagem está entre 0\% e 100\%.
# - A proporção 0,34 significa 34\%.

# %% [markdown]
# ### Visualizações ruins
#
# - Conforme mencionado anteriormente, as visualizações nos permitem identificar facilmente tendências e comunicar nossos resultados a outras pessoas.
# - Algumas visualizações tornam mais difícil ver a tendência nos dados,
#  - Por exemplo, gráficos de Pizza! EVITE-OS!!!
#  - Gráficos 3D, se pergunte se é necessário realmente!!
#  - Proporção dos gráficos

# %% [markdown]
# <img src="https://cdn.prod.website-files.com/64ccd6239abfeec743815b28/663b80b84951fd4b0f41f3e3_qu9vCjLZVBEs7aeq1emi2kydxt0tWg_rcGkV4H1DzkF_93SrtRld-mcZn5YvAqF1osJyMsv5YzjTemJWPanfUa0WjFEpjqyo4-KlQz6vpAFQHiE5tYmwuA3QWEY9ETrZJPfYkeRaIDBfwHugbJSXRH0.png" width=400>
#
# fonte: https://www.luzmo.com/blog/bad-data-visualization

# %% [markdown]
# ## Resumo
#
# - As visualizações facilitam a extração de padrões de conjuntos de dados.
# - Existem dois tipos principais de variáveis: categóricas e numéricas.
# - Os tipos de variáveis ​​que estamos visualizando informam nossa escolha de qual tipo de visualização usar.
# - Hoje, analisamos gráficos de dispersão, gráficos de linhas e gráficos de barras.

# %% [markdown]
# ## 5. Exercícios
#
# Vamos agora repetir os códigos visto acima, mas para a base de dados das músicas mais tocadas no dia dos pais no Brasil.
#
# Todas as perguntas podem ser respondidas baseadas nos códigos visto neste Colab.
#
# Primeiramente, vamos carregar o dataframe que chamaremos de `top_brasil`

# %%
top_brasil = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')
top_brasil
# Out:
#      rank                                   uri                artist_names  \
# 0       1  spotify:track:7tI8dRuH2Yc6RuoTjxo4dU                       Jimin
# 1       2  spotify:track:6dOtVTDdiauQNBQEDOtlAB               Billie Eilish
# 2       3  spotify:track:2qSkIjg1o9h3YT9RAgYN75           Sabrina Carpenter
# 3       4  spotify:track:5N3hjp1WNayUPZrA8kJmJP           Sabrina Carpenter
# 4       5  spotify:track:6WatFBLVB0x077xWeoVc2k                     KAROL G
# ..    ...                                   ...                         ...
# 195   196  spotify:track:0LZy30mVmxqUpdQmaXKXBd      Myke Towers, Bad Bunny
# 196   197  spotify:track:6JIC3hbC28JZKZ8AlAqX8h  Elton John, Dua Lipa, PNAU
# 197   198  spotify:track:7fveJ3pk1eSfxBdVkzdXZ0       Morgan Wallen, ERNEST
# 198   199  spotify:track:0pqnGHJpmpxLKifKRmU6WP             Imagine Dragons
# 199   200  spotify:track:2nMeu6UenVvwUktBCpLMK9                Lana Del Rey
#
#                        track_name  \
# ...

# %% [markdown]
# ### 1 - musicas mais populares
#
# Apresentar um gráfico de barra horizontal contendo as 10 músicas mais populares têm

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carrega o dataframe a partir do arquivo CSV
df = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')

# Seleciona as 10 músicas mais populares
top_10_songs = df.sort_values(by='streams', ascending=False).head(10)

# Cria o gráfico de barras horizontal
plt.figure(figsize=(10, 5))
plt.barh(top_10_songs['track_name'], top_10_songs['streams'], color='skyblue')
plt.xlabel('Streams')
plt.ylabel('Música')
plt.title('10 Músicas Mais Populares')
plt.show()

# %% [markdown]
# ### 2 - Número de música no rank dos top artistas
#
# Apresentar um gráfico de barra horizontal do número de musicas que cada um entre os 10 melhores artistas estiveram no Top Streaming.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carrega o dataframe a partir do arquivo CSV
df = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')

# Agrupa por artista e conta o número de músicas
artist_counts = df.groupby('artist_names')['track_name'].nunique()

# Seleciona os 10 melhores artistas
top_10_artists = artist_counts.sort_values(ascending=False).head(10)

# Cria o gráfico de barras horizontal
plt.figure(figsize=(10, 5))
plt.barh(top_10_artists.index, top_10_artists.values, color='coral')
plt.xlabel('Número de Músicas')
plt.ylabel('Artista')
plt.title('Número de Músicas no Top Streaming por Artista')
plt.show()

# %% [markdown]
# ### 3 -Streams do artista mais tocado
#
# Apresentar um gráfico de barra  de quantos streams tiveram cada música do artista mais tocado (ver exemplo da seção músicas em destaque)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carrega o dataframe a partir do arquivo CSV
df = pd.read_csv('http://www.inf.ufes.br/~vinicius.mota/Intro-IA-CD/04-dataviz/data/regional-global-daily-2024-08-11.csv')

# Encontra o artista com mais streams
top_artist = df.groupby('artist_names')['streams'].sum().idxmax()

# Filtra o dataframe para o artista mais tocado
top_artist_songs = df[df['artist_names'] == top_artist]

# Cria o gráfico de barras
plt.figure(figsize=(10, 5))
plt.bar(top_artist_songs['track_name'], top_artist_songs['streams'], color='mediumseagreen')
plt.xlabel('Música')
plt.ylabel('Streams')
plt.title('Streams das Músicas de {}'.format(top_artist))
plt.xticks(rotation=45, ha='right')
plt.show()
